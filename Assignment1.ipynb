# %% [markdown]
# # NAME: VARUN SACHDEVA
# # SAP ID: 590015987
# # PYTHON ASSIGNMENT 1

# %% [markdown]
# ## Part 1: Introduction to python

# %% [markdown]
# #### 1.1: Python installation and execution

# %% [markdown]
# #### Ques 1)write a python script that prints your name ,Course name and the Python version you are using execute the command from the command line and include a screenshot of the output

# %% [markdown]
# ![image.png](attachment:6f4f9fdf-5048-416e-af19-cac29346aa33.png)

# %% [markdown]
# ![image.png](attachment:4a372a68-4df7-4786-a196-c6c76722ab76.png)

# %% [markdown]
# #### 1.2: Using IDLE

# %% [markdown]
# #### Ques 2) Open idle and write a python script that print hello Python world save the script as hello.py and execute it using idle

# %% [markdown]
# ![image.png](attachment:0baf479c-2d9e-47c3-ae42-887e7e2cb98a.png)

# %% [markdown]
# ![image.png](attachment:99ba055e-d38c-4e2f-a91c-dda342bf7872.png)

# %% [markdown]
# ## Part 2: Basic python syntax

# %% [markdown]
# #### 2.1: String Operations

# %% [markdown]
# #### Ques 3) Write a Python program that takes a user's first and last name as input and prints them in reverse order with a space between them.

# %%
firstName=input("Enter Your First Name: ") #Taking First name as input
lastName=input("Enter Your Last Name: ") #Taking last name as input
fullName=firstName+" "+lastName #Merging First and last name 
reversedName = fullName[::-1] #reverse full name using slicing
print(reversedName) #Printing Reversed name
# Out:
# Enter Your First Name:  VARUN
# Enter Your Last Name:  SACHDEVA
# AVEDHCAS NURAV

# %% [markdown]
# #### Ques 4) Use at least two string methods and explain their purpose in the comments

# %%
str1="welcome varun!"
print("Method 1: ",str1.capitalize())#Convert First character of first word to uppercase
str2="Welcome Varun!"
print("Method 2: ",str2.swapcase())#Swap the case of all character it converts lowercase to uppercase and uppercase to lowercase
# Out:
# Method 1:  Welcome varun!
# Method 2:  wELCOME vARUN!

# %% [markdown]
# #### 2.2: Numeric Data Types and Conversion Functions

# %% [markdown]
# #### Ques 5) write a Python program that takes an input number from the user converts it to different numeric data type (integer, float and complex) and display the converted values

# %%
num=input("Enter number: ") #Taking input from user
intnum=int(num) #Integer (int): Represents whole numbers without decimals (e.g., 5, -3).
floatnum=float(num) #Float (float): Represents real numbers with decimal points (e.g., 3.14, -0.001).
compnum=complex(num) #Complex (complex): Represents numbers with a real and an imaginary part (e.g., 2 + 3j, -1j).
print("\nInteger Form: ", intnum)
print("Float Form: ", floatnum)
print("Complex Form: ", compnum)
# Out:
# Enter number:  45
# Integer Form:  45
# Float Form:  45.0
# Complex Form:  (45+0j)

# %% [markdown]
# #### 2.3: Simple Input and Output

# %% [markdown]
# #### Ques 6) create a python script that calculate the area of a rectangle the script should prompt the user to enter the Length and width of the rectangle calculate the area display the result using the print function

# %%
# Taking length and breadth as input
length=int(input("Enter Length: "))
breadth=int(input("Enter Breadth: "))
# Creatind function to calculate area
def arearec(l,b):
    area=l*b
    print("Area: ",area)
arearec(length,breadth)  # Calling functiion
# Out:
# Enter Length:  12
# Enter Breadth:  5
# Area:  60

# %% [markdown]
# #### 2.4: Using the format Method

# %% [markdown]
# #### Ques 7) modify the rectangle area program to format the output so that it displays the area with two decimal places

# %%
def arearec(l,b):
    area=l*b
    print("Area: {:.2f}".format(area))  #Using slicing and format method to print 
arearec(length,breadth)
# Out:
# Area: 60.00

# %% [markdown]
# #### 2.5: The % Method and Print Function

# %% [markdown]
# #### Ques 8) write a python script that takes three numbers as input and print their average using the % method for sring formatting also use the print function to display a message that States the average of the three numbers is [calculated average]

# %%
#Taking inputs
num1=int(input("Enter First Number: "))  
num2=int(input("Enter Second Number: "))
num3=int(input("Enter Third Number: "))
average=(num1+num2+num3)/3  #calculating average
print("The average of the three numbers is: %d"%(average)) #Printing average using % method
print("The average of the three numbers is: ",int(average)) #Printing average using print function
# Out:
# Enter First Number:  3
# Enter Second Number:  4
# Enter Third Number:  5
# The average of the three numbers is: 4
# The average of the three numbers is:  4

# %% [markdown]
# ## Part 3: Language Components

# %% [markdown]
# #### 3.1: Control flow (if statements and loops)

# %% [markdown]
# #### Ques 9) write a Python program that asks the user for a number and determine whether it is positive negative or zero implement a loop that continues to ask the user for a number until they entre exit use break to exit the loop and continue to prompt for a new number if the input is not exit.

# %%
while True:
    num=input("Enter Number: ")
    if num.lower() == 'exit':
        print("Exited!")
        break
    # Try to convert the input to a float
    try:
        num = int(num)
        # Determine if the number is positive, negative, or zero
        if num > 0:
            print(f"Number {num} is positive.")
        elif num < 0:
            print(f"Number {num} is negative.")
        else:
            print(f"Number {num} is zero.")  
    except ValueError:
        print("Invalid input!")
# Out:
# Enter Number:  45
# Number 45 is positive.
# Enter Number:  0
# Number 0 is zero.
# Enter Number:  -45
# Number -45 is negative.
# Enter Number:  exit
# Exited!

# %% [markdown]
# #### 3.2: Relational and Logical Operators

# %% [markdown]
# #### Ques 10) create a python script that takes two numbers as input and prints whether both numbers are even odd or one of each using relational and logical operators.

# %%
# Take input from the user
num1 = int(input("Enter the first number: "))
num2 = int(input("Enter the second number: "))

# Check if both numbers are even
if num1 % 2 == 0 and num2 % 2 == 0:
    print("Both numbers are even.")
# Check if both numbers are odd
elif num1 % 2 != 0 and num2 % 2 != 0:
    print("Both numbers are odd.")
else:
    print("One number is even and one is odd.")

# %% [markdown]
# #### 3.3: For loop and bitwise operators

# %% [markdown]
# #### Ques 11) write a Python program that takes an integer Input and print its binary octal and hexadecimal equivalent using a for loop and bitwise operators.

# %%
def convert_number(num):
    print(f"Decimal: {num}")
    
    # Binary
    print("Binary: ", end="")
    for i in range(31, -1, -1):
        print(1 if num & (1 << i) else 0, end="")
    print()
    
    # Octal
    print("Octal: {:o}".format(num))
    
    # Hexadecimal
    print("Hexadecimal: {:X}".format(num))

# Get user input
decimal_num = int(input("Enter a decimal number: "))

# Call the function to convert the number
convert_number(decimal_num)
